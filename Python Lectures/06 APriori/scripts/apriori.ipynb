# %% [markdown]
# ## A Priori Algorithm

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

import mlxtend
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
from mlxtend.preprocessing import TransactionEncoder

# %% [markdown]
# ### Preprocessing

# %%
df = pd.read_csv('../data/Online_Retail.csv')

# Remove spaces at the beginning and the end
df['Description'] = df['Description'].str.strip()  

# Drop rows which contain missing values
df.dropna(axis = 0, subset = ['InvoiceNo'], inplace = True)

# Change column InvoiceNotype to String
df['InvoiceNo'] = df['InvoiceNo'].astype('str')

# Re-construct dfby removing rows that have column “InvoiceNo” contain “C”
df = df[~df['InvoiceNo'].str.contains('C')]
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
basket = (df[df['Country'] == 'France'].groupby(['InvoiceNo', 'Description'])['Quantity']
        .sum()
        .unstack()
        .reset_index()
        .fillna(0)
        .set_index('InvoiceNo')
        )
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
# ...                             ...                         ...
# 580986                          0.0                         0.0
# 581001                          0.0                         0.0
# 581171                          0.0                         0.0
# 581279                          0.0                         0.0
# 581587                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# ...

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace = True, axis = 1)
basket_sets.head()
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# 536852                               0                                0
# 536974                               0                                0
# 537065                               0                                0
# 537463                               0                                0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                   0
# ...

# %%
# Generate the frequent item sets that have a support of at least 7%
frequent_itemsets = apriori(basket_sets, min_support = 0.07, use_colnames = True)

# Select theat have the lift greater than 1.00
rules = association_rules(frequent_itemsets, metric = 'lift', min_threshold = 1)
rules[(rules['lift'] >= 6.00) & (rules['confidence'] >= 0.80)]
# Out:
#                                           antecedents  \
# 2                          (ALARM CLOCK BAKELIKE RED)
# 3                        (ALARM CLOCK BAKELIKE GREEN)
# 17                    (SET/6 RED SPOTTY PAPER PLATES)
# 18                    (SET/6 RED SPOTTY PAPER PLATES)
# 19                      (SET/6 RED SPOTTY PAPER CUPS)
# 20  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 21  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 22  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
#
#                              consequents  antecedent support  \
# 2           (ALARM CLOCK BAKELIKE GREEN)            0.094388
# 3             (ALARM CLOCK BAKELIKE RED)            0.096939
# 17  (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
# 18         (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 19       (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 20         (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# ...

# %%
basket['ALARM CLOCK BAKELIKE GREEN'].sum()
basket['ALARM CLOCK BAKELIKE RED'].sum()
# Out:
# 316.0

# %%
basket2 = (df[df['Country'] == 'Germany']
    .groupby(['InvoiceNo', 'Description'])['Quantity']
    .sum().unstack().reset_index().fillna(0)
    .set_index('InvoiceNo')
    )

basket_sets2 = basket2.applymap(encode_units)
basket_sets2.drop('POSTAGE', inplace = True, axis = 1)

# %%
frequent_itemsets2 = apriori(basket_sets2, min_support = 0.05, use_colnames = True)
rules2 = association_rules(frequent_itemsets2, metric = 'lift', min_threshold = 1)

filter_rules2 = rules2[(rules2['lift'] >= 4) & (rules2['confidence'] >= 0.5)]
filter_rules2
# Out:
#                         antecedents                         consequents  \
# 1   (PLASTERS IN TIN CIRCUS PARADE)  (PLASTERS IN TIN WOODLAND ANIMALS)
# 7        (PLASTERS IN TIN SPACEBOY)  (PLASTERS IN TIN WOODLAND ANIMALS)
# 11    (RED RETROSPOT CHARLOTTE BAG)            (WOODLAND CHARLOTTE BAG)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 1             0.115974            0.137856  0.067834    0.584906  4.242887
# 7             0.107221            0.137856  0.061269    0.571429  4.145125
# 11            0.070022            0.126915  0.059081    0.843750  6.648168
#
#     leverage  conviction
# 1   0.051846    2.076984
# 7   0.046488    2.011670
# 11  0.050194    5.587746

# %% [markdown]
# ### Dataset 2

# %%
dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df2 = pd.DataFrame(te_ary, columns = te.columns_)
df2
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %%
frequent_itemsets3 = apriori(df2, min_support = 0.05, use_colnames = True)
rules3 = association_rules(frequent_itemsets3, metric = 'lift', min_threshold = 1)

# %%
filter_rules3 = rules3[ (rules3['lift'] >= 4) & (rules3['confidence'] >= 0.5)]
# filter_rules3[ filter_rules3['antecedents'] == frozenset(('Corn', 'Eggs')) ]
# filter_rules3[ filter_rules3['consequents'] == frozenset(('Corn', 'Eggs')) ]
# filter_rules3[ filter_rules3['consequents'] == frozenset({'Ice cream'}) ]

rules3[rules3['consequents'] == frozenset({'Corn', 'Eggs'})]
# Out:
#                           antecedents   consequents  antecedent support  \
# 79                        (Ice cream)  (Corn, Eggs)                 0.2
# 81                     (Kidney Beans)  (Corn, Eggs)                 1.0
# 85                            (Onion)  (Corn, Eggs)                 0.6
# 328         (Kidney Beans, Ice cream)  (Corn, Eggs)                 0.2
# 345                (Onion, Ice cream)  (Corn, Eggs)                 0.2
# 354             (Kidney Beans, Onion)  (Corn, Eggs)                 0.6
# 767  (Kidney Beans, Onion, Ice cream)  (Eggs, Corn)                 0.2
#
#      consequent support  support  confidence      lift  leverage  conviction
# 79                  0.2      0.2    1.000000  5.000000      0.16         inf
# 81                  0.2      0.2    0.200000  1.000000      0.00         1.0
# 85                  0.2      0.2    0.333333  1.666667      0.08         1.2
# 328                 0.2      0.2    1.000000  5.000000      0.16         inf
# ...
